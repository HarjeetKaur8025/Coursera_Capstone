# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Data Wrangling Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be performing data wrangling.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify duplicate values in the dataset.
#
# -   Remove duplicate values from the dataset.
#
# -   Identify missing values in the dataset.
#
# -   Impute the missing values in the dataset.
#
# -   Normalize data in the dataset.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv")

# %%
df.tail()
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 11547       25136  I am a developer by profession      Yes
# 11548       25137  I am a developer by profession      Yes
# 11549       25138  I am a developer by profession      Yes
# 11550       25141  I am a developer by profession      Yes
# 11551       25142  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 11547                                              Never
# 11548                                              Never
# 11549                            Less than once per year
# 11550  Less than once a month but more than once per ...
# 11551  Less than once a month but more than once per ...
#
#                                               OpenSource          Employment  \
# 11547  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 11548  The quality of OSS and closed source software ...  Employed full-time
# ...

# %%
df.describe()
# Out:
#          Respondent     CompTotal  ConvertedComp   WorkWeekHrs   CodeRevHrs  \
# count  11552.000000  1.073700e+04   1.073000e+04  11427.000000  9083.000000
# mean   12362.212517  7.499932e+05   1.313340e+05     42.051851     4.762829
# std     7271.939210  9.639522e+06   2.943245e+05     24.528561     4.548401
# min        4.000000  0.000000e+00   0.000000e+00      3.000000     0.000000
# 25%     6011.500000  2.500000e+04   2.672700e+04     40.000000     2.000000
# 50%    12323.500000  6.500000e+04   5.774400e+04     40.000000     4.000000
# 75%    18686.500000  1.200000e+05   1.000000e+05     43.000000     5.000000
# max    25142.000000  7.000000e+08   2.000000e+06   1012.000000    99.000000
#
#                 Age
# count  11255.000000
# mean      30.772394
# std        7.392780
# min       16.000000
# 25%       25.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11552 entries, 0 to 11551
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              11552 non-null  int64
#  1   MainBranch              11552 non-null  object
#  2   Hobbyist                11552 non-null  object
#  3   OpenSourcer             11552 non-null  object
#  4   OpenSource              11471 non-null  object
#  5   Employment              11552 non-null  object
#  6   Country                 11552 non-null  object
#  7   Student                 11499 non-null  object
#  8   EdLevel                 11436 non-null  object
#  9   UndergradMajor          10812 non-null  object
#  10  EduOther                11388 non-null  object
#  11  OrgSize                 11454 non-null  object
#  12  DevType                 11485 non-null  object
#  13  YearsCode               11543 non-null  object
# ...

# %% [markdown]
# ## Finding duplicates

# %% [markdown]
# In this section you will identify duplicate values in the dataset.

# %% [markdown]
#  Find how many duplicate rows exist in the dataframe.

# %%
#1st method 
#duplicated() method returns boolean pandas.Series with duplicate rows as True. By default, all columns are used to determine if a row is a duplicate or not.
dup= df.duplicated(subset=None, keep='first')
dup
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11547    False
# 11548    False
# 11549    False
# 11550    False
# 11551    False
# Length: 11552, dtype: bool

# %%
dup.sum()
# Out:
# 154

# %%
#You can use this pandas.Series to extract duplicate rows from the original pandas.DataFrame.
print(df[df.duplicated()])
# Out:
#       Respondent                                         MainBranch Hobbyist  \
# 1168        2339                     I am a developer by profession      Yes
# 1169        2342                     I am a developer by profession      Yes
# 1170        2343                     I am a developer by profession      Yes
# 1171        2344                     I am a developer by profession      Yes
# 1172        2347                     I am a developer by profession      Yes
# ...          ...                                                ...      ...
# 2297        4674  I am not primarily a developer, but I write co...      Yes
# 2298        4675                     I am a developer by profession      Yes
# 2299        4676                     I am a developer by profession      Yes
# 2300        4677                     I am a developer by profession      Yes
# 2301        4679                     I am a developer by profession      Yes
#
# ...

# %% [markdown]
# ## Removing duplicates

# %% [markdown]
# Remove the duplicate rows from the dataframe.

# %%
dups1= df.drop_duplicates(subset="Respondent",keep='first', inplace=False)
dups1
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 0               4  I am a developer by profession       No
# 1               9  I am a developer by profession      Yes
# 2              13  I am a developer by profession      Yes
# 3              16  I am a developer by profession      Yes
# 4              17  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 11547       25136  I am a developer by profession      Yes
# 11548       25137  I am a developer by profession      Yes
# 11549       25138  I am a developer by profession      Yes
# 11550       25141  I am a developer by profession      Yes
# 11551       25142  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                             Once a month or more often
# 2      Less than once a month but more than once per ...
# ...

# %% [markdown]
# Verify if duplicates were actually dropped.

# %%
len(dups1)
# Out:
# 11398

# %% [markdown]
# ## Finding Missing values

# %%
#To check if there are any missing values in our data frame:
(dups1.isnull().values.any())
# Out:
# True

# %% [markdown]
# Find the missing values for all columns.

# %%
#filtering out the columns from the new cleaned Dataframe by using data type 
dups1.dtypes == 'object'
# Out:
# Respondent      False
# MainBranch       True
# Hobbyist         True
# OpenSourcer      True
# OpenSource       True
#                 ...
# Sexuality        True
# Ethnicity        True
# Dependents       True
# SurveyLength     True
# SurveyEase       True
# Length: 85, dtype: bool

# %%
#seperate numerical variables and categorical variables
numerical_variables = dups1.columns[dups1.dtypes != 'object']
categorical_variables = dups1.columns[dups1.dtypes == 'object']
print (numerical_variables)
print (categorical_variables)
# Out:
# Index(['Respondent', 'CompTotal', 'ConvertedComp', 'WorkWeekHrs', 'CodeRevHrs',
#        'Age'],
#       dtype='object')
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompFreq', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'UnitTests', 'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
# ...

# %%
dups1[numerical_variables]
# Out:
#        Respondent  CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs   Age
# 0               4    61000.0        61000.0         80.0         NaN  22.0
# 1               9   138000.0        95179.0         32.0        12.0  23.0
# 2              13    90000.0        90000.0         40.0         5.0  28.0
# 3              16    29000.0       455352.0         40.0         NaN  26.0
# 4              17    90000.0        65277.0         45.0         5.0  29.0
# ...           ...        ...            ...          ...         ...   ...
# 11547       25136   130000.0       130000.0         40.0         NaN  36.0
# 11548       25137    74400.0        19880.0         40.0         5.0  25.0
# 11549       25138   105000.0       105000.0         40.0         5.0  34.0
# 11550       25141    80000.0        80371.0         42.5         2.0  25.0
# 11551       25142        NaN            NaN         80.0         1.0  30.0
#
# [11398 rows x 6 columns]

# %%
dups1[categorical_variables]
# Out:
#                            MainBranch Hobbyist  \
# 0      I am a developer by profession       No
# 1      I am a developer by profession      Yes
# 2      I am a developer by profession      Yes
# 3      I am a developer by profession      Yes
# 4      I am a developer by profession      Yes
# ...                               ...      ...
# 11547  I am a developer by profession      Yes
# 11548  I am a developer by profession      Yes
# 11549  I am a developer by profession      Yes
# 11550  I am a developer by profession      Yes
# 11551  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                             Once a month or more often
# 2      Less than once a month but more than once per ...
# 3                                                  Never
# 4      Less than once a month but more than once per ...
# ...

# %%
dups1.dropna()
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 6              20  I am not primarily a developer, but I write co...       No
# 15             39                     I am a developer by profession      Yes
# 17             44                     I am a developer by profession      Yes
# 36             83                     I am a developer by profession      Yes
# 47            104                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 11474       24975                     I am a developer by profession      Yes
# 11475       24977                     I am a developer by profession      Yes
# 11478       24985                     I am a developer by profession      Yes
# 11499       25022  I am not primarily a developer, but I write co...      Yes
# 11538       25118                     I am a developer by profession      Yes
#
# ...

# %%
len(dups1)
# Out:
# 11398

# %%
#printing out the columns from the new cleaned Dataframe by using data type 
#you can use either of the code in 11, 12, 13 to get result 
print(dups1.isnull().sum())
# Out:
# Respondent        0
# MainBranch        0
# Hobbyist          0
# OpenSourcer       0
# OpenSource       81
#                ...
# Sexuality       542
# Ethnicity       675
# Dependents      140
# SurveyLength     19
# SurveyEase       14
# Length: 85, dtype: int64

# %%
#printing out the columns from the new cleaned Dataframe by using data type 
#you can use either of the code in 11, 12, 13 to get result 
dups1.apply(lambda x: sum(x.isnull().values), axis = 0) # For columns
# Out:
# Respondent        0
# MainBranch        0
# Hobbyist          0
# OpenSourcer       0
# OpenSource       81
#                ...
# Sexuality       542
# Ethnicity       675
# Dependents      140
# SurveyLength     19
# SurveyEase       14
# Length: 85, dtype: int64

# %% [markdown]
# ### Under the column " UndergradMajor", which category has the minimum number of rows?

# %%
print(dups1['UndergradMajor'].isnull().min())
# Out:
# False

# %%
dups1['UndergradMajor'].min(axis=None, skipna=None, level=None, numeric_only=None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-e1301df66640> in <module>
# ----> 1 dups1['UndergradMajor'].min(axis=None, skipna=None, level=None, numeric_only=None)
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11213             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
#   11214         return self._reduce(
# > 11215             f, name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11216         )
#   11217
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3889                 )
#    3890             with np.errstate(all="ignore"):
# ...

# %%
dups1.head()
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...

# %%
# Create a DataFrame object
dups1Obj = pd.dups1(index=list('012345%'), columns='UndergradMajor')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-fece179f64a6> in <module>
#       1 # Create a DataFrame object
# ----> 2 dups1Obj = pd.dups1(index=list('012345%'), columns='UndergradMajor')
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/__init__.py in __getattr__(name)
#     261             return _SparseArray
#     262
# --> 263         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     264
#     265
#
# AttributeError: module 'pandas' has no attribute 'dups1'

# %%
# Get a series containing minimum value of each column
minValuesObj = dups1Obj.min()
print('minimum value in each column : ')
print(minValuesObj)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-4eeee08be981> in <module>
#       1 # Get a series containing minimum value of each column
# ----> 2 minValuesObj = dups1Obj.min()
#       3 print('minimum value in each column : ')
#       4 print(minValuesObj)
#
# NameError: name 'dups1Obj' is not defined

# %%
# Get a series containing minimum value of each row
minValuesObj = dups1Obj.min(axis=1)
print('minimum value in each row : ')
print(minValuesObj)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-a65e48cb7d2d> in <module>
#       1 # Get a series containing minimum value of each row
# ----> 2 minValuesObj = dups1Obj.min(axis=1)
#       3 print('minimum value in each row : ')
#       4 print(minValuesObj)
#
# NameError: name 'dups1Obj' is not defined

# %% [markdown]
# Find out how many rows are missing in the column 'WorkLoc'

# %%
dups1['WorkLoc'].isna().sum()
# Out:
# 32

# %% [markdown]
# ## Imputing missing values

# %% [markdown]
# Find the  value counts for the column WorkLoc.

# %%
dups1['WorkLoc'].value_counts()
# Out:
# Office                                            6806
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: WorkLoc, dtype: int64

# %% [markdown]
# Identify the value that is most frequent (majority) in the WorkLoc column.

# %%
import numpy as np
from collections import Counter

# %%
# Creating a counter object
count = Counter(dups1['WorkLoc'])
# Calling a method of Counter object(count)
count.most_common(3)
# Out:
# [('Office', 6806),
#  ('Home', 3589),
#  ('Other place, such as a coworking space or cafe', 971)]

# %%
dups1["WorkLoc"].value_counts().nlargest(n=1).values[0]
# Out:
# 6806

# %%
dups1['WorkLoc'].head()
# Out:
# 0                                              Home
# 1                                            Office
# 2                                              Home
# 3                                              Home
# 4    Other place, such as a coworking space or cafe
# Name: WorkLoc, dtype: object

# %% [markdown]
# Impute (replace) all the empty rows in the column WorkLoc with the value that you have identified as majority.

# %%
dups1['WorkLoc'].replace({" ": 6806, "NaN" : 6806}, inplace=True)
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %% [markdown]
# After imputation there should ideally not be any empty rows in the WorkLoc column.

# %% [markdown]
# Verify if imputing was successful.

# %%
print (dups1['WorkLoc'].head(10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'WorkLoc'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-a0e4fced1c28> in <module>
# ...

# %% [markdown]
# ## Normalizing data

# %% [markdown]
# There are two columns in the dataset that talk about compensation.
#
# One is "CompFreq". This column shows how often a developer is paid (Yearly, Monthly, Weekly).
#
# The other is "CompTotal". This column talks about how much the developer is paid per Year, Month, or Week depending upon his/her "CompFreq".
#
# This makes it difficult to compare the total compensation of the developers.
#
# In this section you will create a new column called 'NormalizedAnnualCompensation' which contains the 'Annual Compensation' irrespective of the 'CompFreq'.
#
# Once this column is ready, it makes comparison of salaries easy.

# %%
# Declare a list that is to be converted into a column
Annual_Compensation = ['Yearly']

dups1 = pd.DataFrame()
dups1['NormalizedAnnualCompensation'] = Annual_Compensation 
dups1.head()
# Out:
#   NormalizedAnnualCompensation
# 0                       Yearly

# %%
def normalize(freq, comp):
    result = 0
    if freq == 'Yearly':
        result = comp
    elif freq == 'Monthly':
        result = comp * 12
    elif freq == 'Weekly':
        result = comp * 52
    return result

# %%
dups1['NormalizedAnnualCompensation'].head()
# Out:
# 0    Yearly
# Name: NormalizedAnnualCompensation, dtype: object

# %% [markdown]
# List out the various categories in the column 'CompFreq'

# %%
dups1['CompFreq'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CompFreq'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-78a2f0bfc355> in <module>
# ...

# %% [markdown]
# Create a new column named 'NormalizedAnnualCompensation'. Use the hint given below if needed.

# %% [markdown]
# Double click to see the **Hint**.
#
# <!--
#
# Use the below logic to arrive at the values for the column NormalizedAnnualCompensation.
#
# If the CompFreq is Yearly then use the exising value in CompTotal
# If the CompFreq is Monthly then multiply the value in CompTotal with 12 (months in an year)
# If the CompFreq is Weekly then multiply the value in CompTotal with 52 (weeks in an year)
#
# -->

# %%
len(dups1)
# Out:
# 11398

# %%
# Declare a list that is to be converted into a column
Annual_Compensation = ['Yearly']

dups1 = pd.DataFrame()
dups1['NormalizedAnnualCompensation'] = Annual_Compensation 
dups1.head()
# Out:
#   NormalizedAnnualCompensation
# 0                       Yearly

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
